# %% [markdown]
# <a href="https://colab.research.google.com/github/JoselynVM/proyecto_ventas/blob/main/analisis_ventas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv('ventas_productos.csv')

#Calcular el precio total
df ['Precio_total'] = df['Cantidad'] * df['Precio']

print(df.head())

plt.bar(df['Producto'], df['Precio_total'])
plt.xlabel('Producto')
plt.ylabel('Precio Total')
plt.title('Precio Total por Producto')
plt.savefig('precio_total_por_producto.png')
plt.show()

print(df ['Precio_total'])
# Out:
#     Producto  Cantidad Precio  \
# 0  Producto1        15    7,0
# 1  Producto2        30    8,5
# 2  Producto3        25    6,5
# 3  Producto4        40   10,0
# 4  Producto5        20    5,5
#
#                                         Precio_total
# 0      7,07,07,07,07,07,07,07,07,07,07,07,07,07,07,0
# 1  8,58,58,58,58,58,58,58,58,58,58,58,58,58,58,58...
# 2  6,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56...
# 3  10,010,010,010,010,010,010,010,010,010,010,010...
# 4  5,55,55,55,55,55,55,55,55,55,55,55,55,55,55,55...
# 0        7,07,07,07,07,07,07,07,07,07,07,07,07,07,07,0
# 1    8,58,58,58,58,58,58,58,58,58,58,58,58,58,58,58...
# 2    6,56,56,56,56,56,56,56,56,56,56,56,56,56,56,56...
# 3    10,010,010,010,010,010,010,010,010,010,010,010...
# 4    5,55,55,55,55,55,55,55,55,55,55,55,55,55,55,55...
# Name: Precio_total, dtype: object
